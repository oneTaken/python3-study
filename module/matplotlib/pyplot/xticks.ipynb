# %% [markdown]
# [matplotlib.pyplot.xticks](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xticks)

# %% [markdown]
# matplotlib.pyplot.xticks(\*args, \*\*kwargs)
#
# Get or set the x-limits of the current tick locations and labels.

# %%
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib import pyplot as plt
# return locs, labels where locs is an array of tick locations and
# labels is an array of tick labels.
locs, labels = xticks()

# set the locations of the xticks
xticks( range(6) )

# set the locations and labels of the xticks
xticks( range(5), ('Tom', 'Dick', 'Harry', 'Sally', 'Sue') )
# Out:
# ([<matplotlib.axis.XTick at 0x6595a58>,
#   <matplotlib.axis.XTick at 0x64cf588>,
#   <matplotlib.axis.XTick at 0x661f6a0>,
#   <matplotlib.axis.XTick at 0x6627668>,
#   <matplotlib.axis.XTick at 0x662e080>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# The keyword args, if any, are Text properties. For example, to rotate long labels:

# %%
import calendar
plt.figure()
plt.plot(range(12))
xticks(range(12), calendar.month_name[1:13], rotation=17 )

plt.figure()
plt.plot(range(12))
